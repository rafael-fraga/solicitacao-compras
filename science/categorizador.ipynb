# %%
import pandas as pd

# %%
produtos = pd.read_csv('produtos.csv')
produtos = produtos.dropna()
produtos
# Out:
#      Unnamed: 0         id                  nome     codigo unidade  \
# 0             1  623449734    ALCATRA COM QUEIJO     ALCAQP      kg
# 1             2  623449795       ALMÔNDEGA BACON   ALMOBARB      kg
# 2             3  623449782      ALMÔNDEGA QUEIJO    ALMOQRB      kg
# 3             4  778208483       ANCHO ALIMENTAR    ANCHALI      kg
# 4             5  646749750        ANCHO DI PRIMA  ANCHDIPDI      kg
# ..          ...        ...                   ...        ...     ...
# 98          143  638867885  T-BONE MINERVA ANGUS   TBONMINE      kg
# 99          144  640758272           T-BONE RARO   TBNERARO      kg
# 100         146  623450791   TOMAHAWK CARA PRETA     TOMACP      kg
# 101         147  647280670         TOMAHAWK RARO   TOMARARO      kg
# 102         148  769175229                TULIPA       TLPA      un
#
#      estoque_minimo       slug             marca
# 0              8.62    Alcatra            Porcão
# 1              5.00  Almôndega  Recheados Brasil
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pyautogui
from time import sleep


login = {
    'bh': {
        'login': 'financeiro2@brazas',
        'senha': 'Brazas2018'
    },
    'rj': {
        'login': 'financeiro@brazasrj',
        'senha': 'Brazas2018'
    },
    'ls': {
        'login': 'financeiro@brazasls',
        'senha': 'Brazas2018'
    }
}


driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(100)

def xpath(path):
    return driver.find_element_by_xpath(path)

def substitute(path, text):
    xpath(path).clear()
    xpath(path).send_keys(text)


for op in ['bh']:

    # login
    driver.get(url='https://tiny.com.br/login')
    xpath('/html/body/section/div/form/div[1]/div[2]/div[2]/input').send_keys(login[op]['login'])
    xpath('/html/body/section/div/form/div[1]/div[2]/div[3]/input').send_keys(login[op]['senha'])
    xpath('/html/body/section/div/form/div[1]/div[2]/div[8]/button').click()
    sleep(1.5)
    pyautogui.press('enter')
    xpath('/html/body/div[6]/div/div[3]/div/div/div/div[1]/div[1]/div/h2')

    # acessar produtos
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\fraga\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# <ipython-input-21-68b60d4ce658>:23: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-21-68b60d4ce658>:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   return driver.find_element_by_xpath(path)

# %%
pyautogui.hotkey('alt', 'tab')
pyautogui.press('enter')

sleep(1)
for sku, marca in zip(produtos['codigo'], produtos['marca']):

    # search
    xpath('/html/body/div[8]/div/div[3]/div[1]/div[3]/div/div/input').clear()
    xpath('/html/body/div[8]/div/div[3]/div[1]/div[3]/div/div/input').send_keys(sku)
    xpath('/html/body/div[8]/div/div[3]/div[1]/div[3]/div/div/span[1]/button').click()

    # pick
    xpath('/html/body/div[8]/div/div[3]/div[2]/div[2]/div/div[1]/form/table/tbody/tr/td[4]').click()
    xpath('/html/body/div[8]/div/div[4]/div[1]/div/button').click()
    xpath('/html/body/div[8]/div/div[4]/div[2]/div[2]/form/div[2]/ul/li[2]/a').click()

    # edit
    xpath('/html/body/div[8]/div/div[4]/div[2]/div[2]/form/div[4]/div[1]/div[2]/div[1]/input[2]').clear()
    xpath('/html/body/div[8]/div/div[4]/div[2]/div[2]/form/div[4]/div[1]/div[2]/div[1]/input[2]').send_keys(marca)
    sleep(0.8)
    pyautogui.press('down')
    pyautogui.press('enter')
    xpath('/html/body/div[8]/div/div[4]/div[2]/div[2]/form/div[14]/div/div/button[1]').click()

    break

    # return
    sleep(0.5)
    driver.get('https://erp.tiny.com.br/produtos#list')
# Out:
# <ipython-input-21-68b60d4ce658>:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   return driver.find_element_by_xpath(path)
