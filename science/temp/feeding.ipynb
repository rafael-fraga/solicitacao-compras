# %% [markdown]
# # Feeding
# retornar json 'produto', 'fornecedor', 'qtd em estoque', 'qtd mínima', 'situacao'

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta, date
import requests, os, json
from time import sleep

# %%
# fazer requisição dos ids de produtos
produtos = list()
data = {'formato': 'json',
        'token': '2b6fc7102240cedcc9166c43921ea73eea82b876',
        'pesquisa': '',
        'pagina': 1}
while True:
  session = requests.post(url='https://api.tiny.com.br/api2/produtos.pesquisa.php', data=data).json()
  data['pagina'] += 1
  try:
    produtos += [x['produto'] for x in session['retorno']['produtos']]
  except:
    break
produtos = pd.DataFrame(produtos)
produtos.set_index('id', inplace=True)
#produtos.drop(['codigo', 'preco', 'preco_promocional', 'gtin', 'tipoVariacao', 'localizacao', 'preco_custo', 'preco_custo_medio', 'situacao'], axis=1, inplace=True)

# %%
produtos
# Out:
#                                  nome     codigo  preco  preco_promocional  \
# id
# 648086180           ADICIONAIS EVENTO  ADCEVENTO    0.0                  0
# 623449734          ALCATRA COM QUEIJO     ALCAQP   74.9                  0
# 623449795             ALMÔNDEGA BACON   ALMOBARB   49.8                  0
# 623449782            ALMÔNDEGA QUEIJO    ALMOQRB   49.8                  0
# 778208483             ANCHO ALIMENTAR    ANCHALI   64.9                  0
# ...                               ...        ...    ...                ...
# 769175229                      TULIPA       TLPA   35.9                  0
# 623450804       WALS LAGOINHA (600ml)    WLSLAG6    8.9                  0
# 623450819  WALS SESSION CITRA (300ml)   WLSSECI3    6.5                  0
# 623450836         WALS VERANO (300ml)   WLSVERA3    6.5                  0
# 623450853         WALS X WALS (600ml)   WLSXWLS6    8.9                  0
#
#           unidade gtin tipoVariacao   localizacao  preco_custo  \
# id
# 648086180      un                 N                       0.00
# 623449734      kg                 N     Freezer B        45.96
# 623449795      kg                 N     Freezer B        28.00
# 623449782      kg                 N     Freezer B        33.00
# 778208483      KG                 N                      44.99
# ...           ...  ...          ...           ...          ...
# 769175229      PÇ                 N                      25.90
# 623450804      Un                 N  Prateleira A         4.50
# 623450819      Un                 N  Prateleira A         4.50
# 623450836      Un                 N  Prateleira A         4.50
# 623450853      Un                 N  Prateleira A         4.50
#
#            preco_custo_medio situacao estoque
# id
# 648086180                0.0        A
# 623449734                0.0        A
# 623449795               14.0        I
# 623449782                0.0        A
# 778208483                0.0        A
# ...                      ...      ...     ...
# 769175229                0.0        A
# 623450804                4.5        I
# 623450819                4.5        I
# 623450836                4.5        I
# 623450853                4.5        I
#
# [153 rows x 12 columns]

# %%
data = {
        'formato': 'json',
        'token': '2b6fc7102240cedcc9166c43921ea73eea82b876',
        'id': 623449734
    }
requests.post(url='https://api.tiny.com.br/api2/produto.obter.php', data=data).json()
# Out:
# {'retorno': {'status_processamento': '3',
#   'status': 'OK',
#   'produto': {'id': '623449734',
#    'nome': 'ALCATRA COM QUEIJO',
#    'codigo': 'ALCAQP',
#    'unidade': 'kg',
#    'preco': 74.9,
#    'preco_promocional': 0,
#    'ncm': '0201.20.20',
#    'origem': '0',
#    'gtin': '',
#    'gtin_embalagem': '',
#    'localizacao': 'Freezer B',
#    'peso_liquido': 1,
#    'peso_bruto': 0,
#    'estoque_minimo': 8.62,
#    'estoque_maximo': 25,
#    'id_fornecedor': '607596173',
#    'codigo_fornecedor': '',
#    'codigo_pelo_fornecedor': '',
#    'unidade_por_caixa': '',
#    'preco_custo': 45.96,
#    'preco_custo_medio': 0,
#    'situacao': 'A',
#    'tipo': 'P',
#    'classe_ipi': '',
#    'valor_ipi_fixo': '0.0000',
#    'cod_lista_servicos': '',
#    'descricao_complementar': '',
#    'garantia': '',
#    'cest': '',
#    'obs': '',
#    'tipoVariacao': 'N',
#    'variacoes': '',
#    'idProdutoPai': '0',
#    'sob_encomenda': 'N',
#    'dias_preparacao': '0',
#    'marca': 'Porcão',
#    'tipoEmbalagem': '2',
#    'alturaEmbalagem': '0.0',
#    'comprimentoEmbalagem': '0.0',
#    'larguraEmbalagem': '0.0',
#    'diametroEmbalagem': '0.0',
#    'categoria': 'Bovinos',
#    'anexos': [{'anexo': 'https://s3-sa-east-1.amazonaws.com/tiny-anexos/erp/NTQ4Mjk2NDI2/b0572b732a4b2eaca73dc2eac7bb5320.jpg'},
#     {'anexo': 'https://s3-sa-east-1.amazonaws.com/tiny-anexos/erp/NTQ4Mjk2NDI2/911a753ce6bad202d5d256326e2610d2.jpg'}],
#    'imagens_externas': [],
#    'classe_produto': 'S',
#    'seo_title': '',
#    'seo_keywords': '',
#    'link_video': '',
#    'seo_description': '',
#    'slug': ''}}}

# %%
# obter estoque para cada produto
for id in produtos.index:
    data = {
        'formato': 'json',
        'token': '2b6fc7102240cedcc9166c43921ea73eea82b876',
        'id': id
    }
    session = requests.post('https://api.tiny.com.br/api2/produto.obter.estoque.php', data=data).json()['retorno']
    try:
        produtos['estoque'].loc[id] = session['produto']['saldo']
    except:
        break#

# %%
produtos_ = produtos.copy()

# %%
json.dumps(produtos.to_dict(orient='records'))
# Out:
# '[{"nome": "ADICIONAIS EVENTO", "unidade": "un", "estoque": 0}, {"nome": "ALCATRA COM QUEIJO", "unidade": "kg", "estoque": 15.06}, {"nome": "ALM\\u00d4NDEGA BACON", "unidade": "kg", "estoque": 0}, {"nome": "ALM\\u00d4NDEGA QUEIJO", "unidade": "kg", "estoque": 0}, {"nome": "ANCHO ALIMENTAR", "unidade": "KG", "estoque": 0}, {"nome": "ANCHO DI PRIMA", "unidade": "kg", "estoque": 0}, {"nome": "ANCHO MINERVA", "unidade": "kg", "estoque": 0}, {"nome": "ANCHO MONTANA STEAKHOUSE", "unidade": "kg", "estoque": 25.28}, {"nome": "ASINHA RECHEADA", "unidade": "Pct", "estoque": 7}, {"nome": "ASSADO DE TIRAS ARG", "unidade": "kg", "estoque": 0}, {"nome": "BACON FATIADO", "unidade": "bandej", "estoque": 0}, {"nome": "BATATA RUSTICA PACOTE", "unidade": "", "estoque": 0}, {"nome": "BRAHMA DUPLO MALTE C 12", "unidade": "cx", "estoque": 0}, {"nome": "BROWNIE NO POTE", "unidade": "", "estoque": 0}, {"nome": "BUTCHER STEAK PORCAO", "unidade": "KG", "estoque": 0}, {"nome": "CACHA\\u00c7A SAGRADA", "unidade": "Un", "estoque": 11}, {"nome": "CAIXAS BRAZAS", "unidade": "un", "estoque": 0}, {"nome": "CARPACCIO CARA PRETA", "unidade": "Un", "estoque": 0}, {"nome": "CARR\\u00c9 CORDEIRO 1953", "unidade": "kg", "estoque": 0}, {"nome": "CARV\\u00c3O", "unidade": "Un", "estoque": 30}, {"nome": "CARV\\u00c3O 10 KG", "unidade": "P\\u00c7", "estoque": 2}, {"nome": "CHOPP 30L", "unidade": "un", "estoque": 0}, {"nome": "CHOPP 50L", "unidade": "un", "estoque": 0}, {"nome": "CHORIZO EST\\u00c2NCIA 92", "unidade": "Kg", "estoque": 10.86}, {"nome": "CHURRASQUEIRO", "unidade": "Un", "estoque": -2}, {"nome": "CONTRA FIL\\u00c9 BIFES", "unidade": "", "estoque": 0}, {"nome": "CONTRA FIL\\u00c9 MINERVA DO MESTRE", "unidade": "", "estoque": 0}, {"nome": "CORA\\u00c7\\u00c3O", "unidade": "kg", "estoque": 8}, {"nome": "COSTELINHA DIA A DIA", "unidade": "kg", "estoque": 0}, {"nome": "COSTELINHA SU\\u00cdNA BBQ", "unidade": "kg", "estoque": 5}, {"nome": "COWBOY CARA PRETA", "unidade": "Kg", "estoque": 64}, {"nome": "COXINHA DA ASA", "unidade": "kg", "estoque": 26}, {"nome": "DENVER CARA PRETA", "unidade": "kg", "estoque": 0}, {"nome": "FAGOTINNI CONCASS\\u00c9", "unidade": "", "estoque": 0}, {"nome": "FRALDA MINERVA", "unidade": "kg", "estoque": 0}, {"nome": "FRALD\\u00c3O BURG", "unidade": "KG", "estoque": 0}, {"nome": "FRALD\\u00c3O URUGUAIO ESTER", "unidade": "kg", "estoque": 1.91}, {"nome": "FRALDINHA ALIMENTAR", "unidade": "KG", "estoque": 0}, {"nome": "FRALDINHA BASSI", "unidade": "kg", "estoque": 0}, {"nome": "FRALDINHA CARA PRETA", "unidade": "Kg", "estoque": 2.68}, {"nome": "FRALDINHA EST\\u00c2NCIA 92", "unidade": "kg", "estoque": 0}, {"nome": "FRALDINHA LS", "unidade": "KG", "estoque": 0}, {"nome": "FRALDINHA MATABOI", "unidade": "kg", "estoque": 0}, {"nome": "FRALDINHA MINERVA", "unidade": "KG", "estoque": 0}, {"nome": "FRALDINHA MONTANA STEAKHOUSE", "unidade": "KG", "estoque": 14.75}, {"nome": "FRALDINHA RED RARO", "unidade": "KG", "estoque": 0}, {"nome": "GIN 1650", "unidade": "", "estoque": 4}, {"nome": "HAMBURGUER CARA PRETA", "unidade": "Un", "estoque": 5}, {"nome": "HAMBURGUER DE TIL\\u00c1PIA", "unidade": "P\\u00c7", "estoque": 16}, {"nome": "KAFTA CHEDDAR", "unidade": "Pct", "estoque": 6}, {"nome": "KIT ALCATRA C/ QUEIJO 5", "unidade": "Un", "estoque": 0}, {"nome": "KIT ALCATRA C/ QUEIJO SUPER PREMIUM 20", "unidade": "Un", "estoque": 0}, {"nome": "KIT CHURRASCO 10", "unidade": "Un", "estoque": 0}, {"nome": "KIT CHURRASCO 15", "unidade": "Un", "estoque": 0}, {"nome": "KIT CHURRASCO 20", "unidade": "Un", "estoque": 0}, {"nome": "KIT CHURRASCO 5", "unidade": "Un", "estoque": 0}, {"nome": "KIT PICANHA SUPER PREMIUM 10", "unidade": "Un", "estoque": 0}, {"nome": "LINGUI\\u00c7A  DE PERNIL PORC\\u00c3O", "unidade": "kg", "estoque": 0}, {"nome": "LINGUI\\u00c7A ARTESANAL DE TIL\\u00c1PIA", "unidade": "KG", "estoque": 17}, {"nome": "LINGUI\\u00c7A CASEIRA BRAZAS BACON", "unidade": "Kg", "estoque": 5}, {"nome": "LINGUI\\u00c7A CASEIRA BRAZAS BACON, QUEIJO E ALHO POR\ ...
